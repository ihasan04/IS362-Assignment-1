# %% [markdown]
# # Ismael Hasan
# ## Assignment 12
#
# **IS 362 - Dr. Charles Pak - CUNY School of Professional Studies**
#
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs <br>
#
# > 1. You’ll need to start by signing up for an API key.
# > 2. Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and
# transform it into a pandas DataFrame.
#
# ![movie%20reviews%20api%20image.png](attachment:movie%20reviews%20api%20image.png)

# %%
import pandas as pd
import numpy as np
import json
import urllib.request

# %% [markdown]
# ***Movie Reviews API***<br>
# ***API Key = sRej566gNm34LQ2mdIlKcCPvAWlANVqA***

# %%
api_key = 'sRej566gNm34LQ2mdIlKcCPvAWlANVqA'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
string = url + '&api-key=' + api_key

# %% [markdown]
# ***Read in the JSON data***

# %%
response = str(urllib.request.urlopen(string).read(), 'utf-8')
movie_reviews = json.loads(response)

# %% [markdown]
# ***Transform JSON data into a pandas DataFrame***

# %%
normalize = pd.json_normalize(movie_reviews['results'])
normalize
# Out:
#                             display_title mpaa_rating  critics_pick  \
# 0   Fireball: Visitors from Darker Worlds                         1
# 1                                Ammonite           R             1
# 2                               Dreamland           R             0
# 3                          The Life Ahead       PG-13             0
# 4                             Wolfwalkers          PG             0
# 5                                 Monsoon                         0
# 6                                 Make Up                         0
# 7                                  Freaky           R             0
# 8                        Greta vs climate                         0
# 9                                  Fatman           R             0
# 10                             Coded Bias                         0
# 11                              Free Time                         0
# 12                              Transhood                         0
# ...
