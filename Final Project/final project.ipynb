# %% [markdown]
# # Ismael Hasan
# ## Final Project
#
# **IS 362 - Dr. Charles Pak - CUNY School of Professional Studies**
#
# **NYC Open Data - 311 Service Requests**
#
# We will analyze __[311 Service Requests](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9/data)__ provided by __[NYC Open Data](https://opendata.cityofnewyork.us/)__. Due to the extensive amount of data within this dataset, we have limited our scope to a sample from the year 2015.
#
# **Our analysis will determine:**
# > 1. Most 311 service requests type
# > 2. Which date received the most 311 service requests
# > 3. Which borough received the most 311 service requests
# > 4. Total 311 service requests
# > 5. Comparison of open and closed 311 service requests
#
# **We will utilize Tableau for the graphical and visual analysis.**
#
# ![logo.png](attachment:logo.png)![nyc%20tech%20office%20logo.png](attachment:nyc%20tech%20office%20logo.png)![NYCOpenData_Logo.png](attachment:NYCOpenData_Logo.png)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ***Read in filtered data - 311 service requests for 2015 only***

# %%
request_data = 'C:/Users/ismae/Desktop/IS362-PAK/Final Project/data/311 service requests 2015.csv'
service_requests = pd.read_csv(request_data)
service_requests.head()
# Out:
#    Unique Key    Created Date     Closed Date Agency  \
# 0    31015465  7/6/2015 10:58  7/22/2015 1:07    DCA
# 1    30997660  7/3/2015 13:26  7/3/2015 14:08   NYPD
# 2    31950223  11/9/2015 3:55  11/9/2015 8:08   NYPD
# 3    31000038   7/3/2015 2:18   7/3/2015 7:54   NYPD
# 4    30995614   7/4/2015 0:03   7/4/2015 3:33   NYPD
#
#                        Agency Name           Complaint Type  \
# 0   Department of Consumer Affairs       Consumer Complaint
# 1  New York City Police Department                  Vending
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department       Noise - Commercial
# 4  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor               Location Type  Incident Zip  \
# 0     Demand for Cash                         NaN       11360.0
# 1  In Prohibited Area  Residential Building/House       10019.0
# 2           No Access             Street/Sidewalk       10453.0
# ...

# %% [markdown]
# ***Replace NaN values with 0*** <br>

# %%
service_requests.replace(np.NaN, 0).head()
# Out:
#    Unique Key    Created Date     Closed Date Agency  \
# 0    31015465  7/6/2015 10:58  7/22/2015 1:07    DCA
# 1    30997660  7/3/2015 13:26  7/3/2015 14:08   NYPD
# 2    31950223  11/9/2015 3:55  11/9/2015 8:08   NYPD
# 3    31000038   7/3/2015 2:18   7/3/2015 7:54   NYPD
# 4    30995614   7/4/2015 0:03   7/4/2015 3:33   NYPD
#
#                        Agency Name           Complaint Type  \
# 0   Department of Consumer Affairs       Consumer Complaint
# 1  New York City Police Department                  Vending
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department       Noise - Commercial
# 4  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor               Location Type  Incident Zip  \
# 0     Demand for Cash                           0       11360.0
# 1  In Prohibited Area  Residential Building/House       10019.0
# 2           No Access             Street/Sidewalk       10453.0
# ...

# %% [markdown]
# ***Evaluate data types for downstream analysis***

# %%
service_requests.dtypes
# Out:
# Unique Key                  int64
# Created Date               object
# Closed Date                object
# Agency                     object
# Agency Name                object
# Complaint Type             object
# Descriptor                 object
# Location Type              object
# Incident Zip              float64
# Incident Address           object
# City                       object
# Status                     object
# Resolution Description     object
# Borough                    object
# dtype: object

# %% [markdown]
# ***Most 311 service requests type*** <br>
# ***We can identify Illegal Parking (29 requests) as the highest Complaint Type***

# %%
service_requests['Complaint Type'].value_counts()
# Out:
# Illegal Parking                  29
# Blocked Driveway                 24
# Noise - Street/Sidewalk          22
# Street Condition                 12
# Noise - Commercial                9
# Consumer Complaint                5
# Overgrown Tree/Branches           4
# Derelict Vehicle                  4
# Root/Sewer/Sidewalk Condition     3
# Damaged Tree                      3
# Broken Muni Meter                 2
# Noise - Park                      2
# HEAT/HOT WATER                    2
# Homeless Encampment               2
# Traffic                           2
# Sidewalk Condition                2
# Standing Water                    2
# Vending                           2
# Noise - Vehicle                   2
# Benefit Card Replacement          2
# Taxi Complaint                    1
# Rodent                            1
# Ferry Complaint                   1
# UNSANITARY CONDITION              1
# Maintenance or Facility           1
# Food Establishment                1
# ...

# %% [markdown]
# ***Save results in a CSV file to create a graphical analysis in Tableau*** <br>

# %%
complaints = 'C:/Users/ismae/Desktop/IS362-PAK/Final Project/data/complaints service requests.csv'
complaints_df = pd.read_csv(complaints)
complaints_df.head()
# Out:
#                 Complaint Types   Totals
# 0  Illegal Parking                     29
# 1     Blocked Driveway                 24
# 2     Noise - Street/Sidewalk          22
# 3      Street Condition                12
# 4         Noise - Commercial            9

# %% [markdown]
# ![complaint%20types%20graph.png](attachment:complaint%20types%20graph.png)

# %% [markdown]
# ***Which date received the most 311 service requests*** <br>
# ***We can identify October 8, 2015 as the date with the most service requests***

# %%
date = service_requests.groupby('Created Date').count()
date.head()
# Out:
#                   Unique Key  Closed Date  Agency  Agency Name  \
# Created Date
# 10/1/2015 7:02             1            1       1            1
# 10/19/2015 13:32           1            1       1            1
# 10/19/2015 7:51            1            1       1            1
# 10/8/2015 10:09            1            1       1            1
# 10/8/2015 13:12            2            2       2            2
#
#                   Complaint Type  Descriptor  Location Type  Incident Zip  \
# Created Date
# 10/1/2015 7:02                 1           1              1             1
# 10/19/2015 13:32               1           1              0             1
# 10/19/2015 7:51                1           1              1             1
# 10/8/2015 10:09                1           1              1             1
# 10/8/2015 13:12                2           2              2             2
#
#                   Incident Address  City  Status  Resolution Description  \
# Created Date
# ...

# %% [markdown]
# ***Create a graphical analysis in Tableau***

# %% [markdown]
# ![date%20graph.png](attachment:date%20graph.png)

# %% [markdown]
# ***Which borough received the most 311 service requests***<br>
# ***We can identify Brooklyn and Queens as the two boroughs with most service requests***

# %%
borough = service_requests.groupby('Borough').count()
borough.head()
# Out:
#                Unique Key  Created Date  Closed Date  Agency  Agency Name  \
# Borough
# BRONX                  29            29           27      29           29
# BROOKLYN               40            40           39      40           40
# MANHATTAN              30            30           29      30           30
# QUEENS                 40            40           38      40           40
# STATEN ISLAND           6             6            6       6            6
#
#                Complaint Type  Descriptor  Location Type  Incident Zip  \
# Borough
# BRONX                      29          29             29            29
# BROOKLYN                   40          40             40            40
# MANHATTAN                  30          28             28            30
# QUEENS                     40          40             35            39
# STATEN ISLAND               6           6              6             6
#
#                Incident Address  City  Status  Resolution Description
# ...

# %% [markdown]
# ***Create a graphical analysis in Tableau***

# %% [markdown]
# ![borough%20chart.png](attachment:borough%20chart.png)

# %% [markdown]
# ***Total 311 service requests***<br>
# ***We can indentify a total number of 149 service requests***

# %%
service_requests['Complaint Type'].count()
# Out:
# 149

# %% [markdown]
# ***Comparison of open and closed 311 service requests***<br>
# ***We can identify 143/149 service requests are closed, 5/149 service requests are open, and 1/149 service requests are pending***

# %%
service_requests['Status'].value_counts()
# Out:
# Closed     143
# Open         5
# Pending      1
# Name: Status, dtype: int64

# %% [markdown]
# ***Create a graphical analysis in Tableau***

# %% [markdown]
# ![open%20and%20closed%20graph.png](attachment:open%20and%20closed%20graph.png)

# %% [markdown]
# ***Final Analysis***<br>
# After analyzing our sample of 311 Service Requests data from 2015, we were successfully able to answer the posed questions during our downstream analysis:<br>
# > 1. Most 311 service requests type - **Illegal Parking**
# > 2. Which date received the most 311 service requests - **October 8, 2015**
# > 3. Which borough received the most 311 service requests - **Brooklyn and Queens**
# > 4. Total 311 service requests - **149**
# > 5. Comparison of open and closed 311 service requests - **143 closed, 5 open, and 1 pending**
