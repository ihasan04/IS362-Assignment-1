# %% [markdown]
# # Ismael Hasan
# ## Project 2
#
# **IS 362 - Dr. Charles Pak - CUNY School of Professional Studies**
#
# The goal of this assignment is to give you practice in preparing different datasets for downstream
# analysis work.

# %% [markdown]
# ## Wide Dataset #3 - NYC Leading Causes of Death
# This is a dataset of the leading causes of deaths in New York City. We will tidy the data and make downstream analyses.

# %%
import numpy as np
import pandas as pd
# %matplotlib notebook

# %% [markdown]
# ***Read and display raw nyc leading causes of death dataset***

# %%
deaths = pd.read_csv('https://raw.githubusercontent.com/pepimartinez/NYC-DeathRates/master/data/raw/New_York_City_Leading_Causes_of_Death.csv')
deaths
# Out:
#       Year                                      Leading Cause Sex  \
# 0     2010            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1     2008  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 2     2013  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 3     2010          Cerebrovascular Disease (Stroke: I60-I69)   M
# 4     2009                 Assault (Homicide: Y87.1, X85-Y09)   M
# ...    ...                                                ...  ..
# 1089  2012            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1090  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 1091  2009              Malignant Neoplasms (Cancer: C00-C97)   M
# 1092  2009    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 1093  2013  Essential Hypertension and Renal Diseases (I10...   M
#
#           Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0               Hispanic    228       18.7                    23.1
# ...

# %% [markdown]
# ***Tidy data (replace "." with "NaN")*** <br>
# ***Drop useless data*** <br>
# ***Reassign string data to int***

# %%
deaths = deaths.replace(to_replace = '.', value = np.nan)
deaths.isnull().sum()
deaths.Deaths = deaths.Deaths.dropna().astype(np.int64)

# %% [markdown]
# ***Sort data by year and deaths***

# %%
deaths.sort_values(['Year', 'Deaths'], ascending=[True,False])
# Out:
#       Year                                      Leading Cause Sex  \
# 814   2007     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 495   2007     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 445   2007              Malignant Neoplasms (Cancer: C00-C97)   F
# 929   2007              Malignant Neoplasms (Cancer: C00-C97)   M
# 91    2007     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# ...    ...                                                ...  ..
# 402   2014                          Alzheimer's Disease (G30)   F
# 822   2014  Congenital Malformations, Deformations, and Ch...   F
# 942   2014  Congenital Malformations, Deformations, and Ch...   F
# 1047  2014  Essential Hypertension and Renal Diseases (I10...   F
# 1071  2014     Chronic Liver Disease and Cirrhosis (K70, K73)   F
#
#              Race Ethnicity  Deaths Death Rate Age Adjusted Death Rate
# 814      White Non-Hispanic  7050.0      491.4                   250.7
# ...

# %% [markdown]
# ***Filter data for deaths for White Non-Hispanic Females*** <br>
# ***Sort by year and deaths***

# %%
deaths[(deaths['Sex'] == 'F') & (deaths['Race Ethnicity'] == 'White Non-Hispanic')].sort_values(by = ['Year' , 'Deaths'])
# Out:
#      Year                                      Leading Cause Sex  \
# 155  2007  Nephritis, Nephrotic Syndrome and Nephrisis (N...   F
# 481  2007                          Alzheimer's Disease (G30)   F
# 627  2007  Essential Hypertension and Renal Diseases (I10...   F
# 594  2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 69   2007                        Diabetes Mellitus (E10-E14)   F
# ..    ...                                                ...  ..
# 145  2014       Chronic Lower Respiratory Diseases (J40-J47)   F
# 101  2014            Influenza (Flu) and Pneumonia (J09-J18)   F
# 948  2014                                   All Other Causes   F
# 611  2014              Malignant Neoplasms (Cancer: C00-C97)   F
# 389  2014     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
#
#          Race Ethnicity  Deaths Death Rate Age Adjusted Death Rate
# 155  White Non-Hispanic    89.0        6.2                     3.5
# ...

# %% [markdown]
# ***Group leading causes of deaths with race ethnicity*** <br>
# ***Sort deaths by race ethnicity***

# %%
deaths_by_race = deaths.groupby(['Race Ethnicity', 'Leading Cause'], as_index = False)['Deaths'].sum()
deaths_by_race.sort_values(['Race Ethnicity', 'Deaths'], ascending = [True,False])
# Out:
#                  Race Ethnicity  \
# 13   Asian and Pacific Islander
# 9    Asian and Pacific Islander
# 1    Asian and Pacific Islander
# 11   Asian and Pacific Islander
# 3    Asian and Pacific Islander
# ..                          ...
# 107          White Non-Hispanic
# 98           White Non-Hispanic
# 105          White Non-Hispanic
# 109          White Non-Hispanic
# 108          White Non-Hispanic
#
#                                          Leading Cause  Deaths
# 13               Malignant Neoplasms (Cancer: C00-C97)  7927.0
# 9       Diseases of Heart (I00-I09, I11, I13, I20-I51)  7509.0
# 1                                     All Other Causes  4597.0
# 11             Influenza (Flu) and Pneumonia (J09-J18)  1328.0
# 3            Cerebrovascular Disease (Stroke: I60-I69)  1233.0
# ..                                                 ...     ...
# 107  Mental and Behavioral Disorders due to Acciden...  2295.0
# 98                           Alzheimer's Disease (G30)  1702.0
# ...

# %% [markdown]
# ***Calculate Top 5: most leading causes of deaths in 2014***

# %%
deaths[deaths['Year'] == 2014].sort_values('Deaths', ascending = False).head(5)
# Out:
#       Year                                   Leading Cause Sex  \
# 389   2014  Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 345   2014  Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 611   2014           Malignant Neoplasms (Cancer: C00-C97)   F
# 1029  2014           Malignant Neoplasms (Cancer: C00-C97)   M
# 948   2014                                All Other Causes   F
#
#           Race Ethnicity  Deaths Death Rate Age Adjusted Death Rate
# 389   White Non-Hispanic  4507.0        318                     161
# 345   White Non-Hispanic  3990.0      297.1                   238.4
# 611   White Non-Hispanic  3153.0      222.5                   150.2
# 1029  White Non-Hispanic  3142.0        234                   195.1
# 948   White Non-Hispanic  2578.0      181.9                   110.7

# %% [markdown]
# ***Calculate Top 5: least leading causes of deaths in 2007***

# %%
deaths[deaths['Year'] == 2007].sort_values('Deaths', ascending = True).head(5)
# Out:
#      Year                                      Leading Cause Sex  \
# 240  2007  Human Immunodeficiency Virus Disease (HIV: B20...   F
# 714  2007    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 509  2007  Essential Hypertension and Renal Diseases (I10...   F
# 57   2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 441  2007  Human Immunodeficiency Virus Disease (HIV: B20...   M
#
#             Race Ethnicity  Deaths Death Rate Age Adjusted Death Rate
# 240     Not Stated/Unknown     5.0        NaN                     NaN
# 714     Not Stated/Unknown     5.0        NaN                     NaN
# 509     Not Stated/Unknown     5.0        NaN                     NaN
# 57   Other Race/ Ethnicity     5.0        NaN                     NaN
# 441     Not Stated/Unknown     6.0        NaN                     NaN

# %% [markdown]
# ***Save the results in another csv file***

# %%
deaths.to_csv('C:/Users/ismae/Desktop/IS362-PAK/Project 2 - Week 6/analyses/deaths_results.csv')
deaths
# Out:
#       Year                                      Leading Cause Sex  \
# 0     2010            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1     2008  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 2     2013  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 3     2010          Cerebrovascular Disease (Stroke: I60-I69)   M
# 4     2009                 Assault (Homicide: Y87.1, X85-Y09)   M
# ...    ...                                                ...  ..
# 1089  2012            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1090  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 1091  2009              Malignant Neoplasms (Cancer: C00-C97)   M
# 1092  2009    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 1093  2013  Essential Hypertension and Renal Diseases (I10...   M
#
#           Race Ethnicity  Deaths Death Rate Age Adjusted Death Rate
# 0               Hispanic   228.0       18.7                    23.1
# ...
